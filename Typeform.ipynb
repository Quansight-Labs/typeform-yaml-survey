# %%
from os import environ

# %%
token = environ.get('TYPEFORM_TOKEN')

# %%
from typeform import Typeform

# %%
typeform = Typeform(token)

# %%
# Create a form by hand and get the 'id'
#res = typeform.forms.create({'title':'Sphinx Survey II', 'fields':
#    []
#})
#res

# %%
import yaml
with open('survey.yml') as f:
    res = yaml.safe_load(f.read())

# %%
typeform.forms.get('Oq55zKog')['fields'][19]
# Out:
# {'id': 'q0HX8KpMIeJc',
#  'title': 'Rate your issues with sphinx concerning *missing features*',
#  'ref': '01JBSTPF9Q1MQ1RXPAAVEG9JSC',
#  'properties': {'description': 'Sphinx is missing features',
#   'start_at_one': False,
#   'steps': 11,
#   'labels': {'left': 'I have all the features I need',
#    'center': 'fre',
#    'right': 'Too many things are missing'}},
#  'validations': {'required': False},
#  'type': 'opinion_scale'}

# %%
with open('survey.yml') as f:
    res = yaml.safe_load(f.read())
questions = []
from copy import deepcopy
for yqu in deepcopy(res):
    q = {}
    if 'type' not in yqu:
        assert 'choices' in yqu, yqu
    q['title'] = yqu.pop('title')
    prop = {}
    if 'description' in yqu:
            prop['description'] = yqu.pop('description')

    if 'choices' in yqu:
        q['type'] = 'multiple_choice'
        
        
        q['properties']=prop
        if yqu.pop('multiple', False):
            prop['allow_multiple_selection'] = True
        if yqu.pop('other', False):
            prop['allow_other_choice'] = True
        prop['choices'] = []
        choices = yqu.pop('choices')
        for c in choices:
            prop['choices'].append({'label':c})
    elif 'type' in yqu and yqu['type'] in ('number', 'statement'):
        q['type'] = yqu.pop('type')
        q['properties'] = prop
    elif yqu['type'] == 'opinion_scale':
        q['type'] = yqu.pop('type')
        if 'start' in yqu:
            start = yqu.pop('start') 
            assert start in (1, 0)
            if start == 1:
                prop['start_at_one'] = True
            if start == 0:
                pass # the default.
        prop['steps'] = yqu.pop('steps', 11)
        if 'labels' in yqu:
            labels = yqu.pop('labels')
            assert len(labels) in [2,3]
            if len(labels) == 2:    
                prop['labels']={'left': labels[0], 'right': labels[1]}
            elif len(labels) == 3:    
                prop['labels']={'left': labels[0], 'center':labels[1],'right': labels[2]}    
                print(prop)
            else:
                assert False
        q['properties'] = prop
    elif yqu['type'] == 'long_text':
        q['type'] = yqu.pop('type')
        # nothing to do
    else:
        assert False
        
    assert not yqu, yqu
    questions.append(q)

typeform.forms.update('Oq55zKog',{'title':'Sphinx Survey oct 17', 'fields':
   questions

})
# Out:
# {'description': 'RST syntax is too complicated', 'steps': 11, 'labels': {'left': 'syntax is great', 'center': 'Just right', 'right': 'syntax is too complicated'}}
# {'id': 'Oq55zKog',
#  'type': 'quiz',
#  'title': 'Sphinx Survey oct 17',
#  'workspace': {'href': 'https://api.typeform.com/workspaces/wDgMRr'},
#  'theme': {'href': 'https://api.typeform.com/themes/qHWOQ7'},
#  'settings': {'language': 'en',
#   'progress_bar': 'proportion',
#   'meta': {'allow_indexing': False},
#   'hide_navigation': False,
#   'is_public': True,
#   'is_trial': False,
#   'show_progress_bar': True,
#   'show_typeform_branding': True,
#   'are_uploads_public': False,
#   'show_time_to_complete': True,
#   'show_number_of_submissions': False,
#   'show_cookie_consent': False,
#   'show_question_number': True,
#   'show_key_hint_on_choices': True,
#   'autosave_progress': True,
#   'free_form_navigation': False,
#   'use_lead_qualification': False,
#   'pro_subdomain_enabled': False},
#  'thankyou_screens': [{'id': 'DefaultTyScreen',
#    'ref': 'default_tys',
#    'title': "Thanks for completing this typeform\nNow *create your own* — it's free, easy, & beautiful",
#    'type': 'thankyou_screen',
#    'properties': {'show_button': True,
#     'share_icons': False,
#     'button_mode': 'default_redirect',
#     'button_text': 'Create a *typeform*'},
#    'attachment': {'type': 'image',
#     'href': 'https://images.typeform.com/images/2dpnUBBkz2VN'}}],
#  'fields': [{'id': 'JkXjwHjoPTEF',
#    'title': 'Sphinx Usage survey 2024',
#    'ref': '01JBSTV8B3RC513BWSC3KJQ68R',
#    'properties': {'description': "This is the sphinx usage survey for 2024, we'd like to understand the main reason you do (not) use sphinx.\nYou can help us improve this survey by submitting a PR to the file that deinfe this survey on GitHub <URL>.\nAnd will be able to find the result in the repository at a later date.\n",
#     'button_text': 'Continue',
#     'hide_marks': False},
#    'type': 'statement'},
#   {'id': '7hf0KdrOxB4S',
#    'title': 'Demographics',
#    'ref': '01JBSTV8B396HZ39TTXFKTH81Y',
#    'properties': {'description': "In this first section, we'd like to know a bit about you, to know who we are adressing to, and whether we are inclusive enough. Feel free to skip questions.",
#     'button_text': 'Continue',
#     'hide_marks': False},
#    'type': 'statement'},
#   {'id': 'h8STPHGElhY9',
#    'title': 'What is your age range',
#    'ref': '01JBSTV8B36B70R4F4G85BZQT6',
#    'properties': {'randomize': False,
#     'allow_multiple_selection': False,
#     'allow_other_choice': False,
#     'vertical_alignment': True,
#     'choices': [{'id': 'XbJziymJ0Pcs',
#       'ref': '01JBSTV8B3D9XY804ZP4JEKNHH',
#       'label': '<15'},
#      {'id': 'kszQvSpovleC',
#       'ref': '01JBSTV8B37KYJGZJ3GS5M4RY6',
#       'label': '15-25'},
#      {'id': 'Q33MCJLqlU2Q',
#       'ref': '01JBSTV8B3X9J3KANX0A0EGD3E',
#       'label': '26-35'},
#      {'id': 'V1fVLMY0SnWJ',
#       'ref': '01JBSTV8B3MHXFX7NM2EXFESY0',
#       'label': '36-45'},
#      {'id': '9kMcdurcpYQO',
#       'ref': '01JBSTV8B3923G0YT2790XTQ4D',
#       'label': '45-55'},
#      {'id': 'XeMAJqX8gl1l',
#       'ref': '01JBSTV8B3BF52N5SK8NM7XF7T',
#       'label': '56-65'},
#      {'id': 'laxK3fHakWym',
#       'ref': '01JBSTV8B3Z2MDTRBSYT917213',
#       'label': '65+'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': 'uIfxoJKi80Cx',
#    'title': 'Which gender do you indentify as',
#    'ref': '01JBSTV8B3QDKE9J22R11NT0BQ',
#    'properties': {'description': 'You can edit the value in Other.',
#     'randomize': False,
#     'allow_multiple_selection': False,
#     'allow_other_choice': True,
#     'vertical_alignment': True,
#     'choices': [{'id': 'tM99eCIAfXbe',
#       'ref': '01JBSTV8B35FC8MRN0ZSRYXD1D',
#       'label': 'Male'},
#      {'id': '0QoHemOvd2Dy',
#       'ref': '01JBSTV8B39AQVYEFDF86VBQKQ',
#       'label': 'Female'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': 'kLqX8wkGt6Gk',
#    'title': 'Do you consider youself as working as part of a team or independant ?',
#    'ref': '01JBSTV8B3HVCG84XFFTJP14T3',
#    'properties': {'description': 'You can select both if both apply',
#     'randomize': False,
#     'allow_multiple_selection': True,
#     'allow_other_choice': False,
#     'vertical_alignment': True,
#     'choices': [{'id': 'AP6H6jFA1h2x',
#       'ref': '01JBSTV8B3DQKKHQRFAGY2SERY',
#       'label': 'Part of team'},
#      {'id': 'PKbNETcaK5dw',
#       'ref': '01JBSTV8B3EH7VAK11DDMWPNC9',
#       'label': 'Independant'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': 'VoqfO3sqTApc',
#    'title': 'Do you consider yourself full-time or hobbyist?',
#    'ref': '01JBSTV8B3X78B9MJ0CEN6DDBS',
#    'properties': {'description': 'That is to say do you mainly code in Python, or one a few hours here and there ?',
#     'randomize': False,
#     'allow_multiple_selection': False,
#     'allow_other_choice': False,
#     'vertical_alignment': True,
#     'choices': [{'id': 'd2NSQVHnW4Dt',
#       'ref': '01JBSTV8B3EC2AKBCRV0M15SEE',
#       'label': 'full-time'},
#      {'id': 'aEzFURDX80Fo',
#       'ref': '01JBSTV8B3WWAKY97W9Y2MJV2M',
#       'label': 'hobbyist'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': '70ksr2Ovz1Om',
#    'title': 'How many year of Python experience you have ?',
#    'ref': '01JBSTV8B3P6F5Z4EXQJYCKG6S',
#    'properties': {},
#    'validations': {'required': False},
#    'type': 'number'},
#   {'id': 'FeMzo2l3BAQt',
#    'title': 'About how you write your doc in general',
#    'ref': '01JBSTV8B34B7618X7WJXS9P7Y',
#    'properties': {'description': 'a short section on how you write docs, even when not using sphinx.',
#     'button_text': 'Continue',
#     'hide_marks': False},
#    'type': 'statement'},
#   {'id': 'AXF7e68mMA3i',
#    'title': 'What documentation engines do you use ?',
#    'ref': '01JBSTV8B3SZJ0DGWSB7MTJMHV',
#    'properties': {'description': 'You can select multiple options, if you also select other, please specifiy as a comma separated list in "other".',
#     'randomize': False,
#     'allow_multiple_selection': True,
#     'allow_other_choice': True,
#     'vertical_alignment': True,
#     'choices': [{'id': 'wds0YzEQwOBu',
#       'ref': '01JBSTV8B3T8SA37KEPWYPR57G',
#       'label': 'MyST'},
#      {'id': 'Eud2TkATLRN1',
#       'ref': '01JBSTV8B3H4ME0A0QHCGCR5A3',
#       'label': 'Docusaurus'},
#      {'id': '4jH37fON9orS',
#       'ref': '01JBSTV8B3YWP2E80E7TV33CBC',
#       'label': 'Mkdocs'},
#      {'id': 'gUdiPg22nXvB',
#       'ref': '01JBSTV8B3K5HBDQD9YVSAFYA7',
#       'label': 'JupyterBook'},
#      {'id': '8kWKIZ9ddmro',
#       'ref': '01JBSTV8B3YW6RQZQ4EA60M8BZ',
#       'label': 'Sphinx'},
#      {'id': '7jmQkwLGu5W4',
#       'ref': '01JBSTV8B3DNYNYQ1HZYMNCRFA',
#       'label': 'None'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': 'VhtmcJy4pN2q',
#    'title': 'If you use Sphinx, In which context do you use sphinx ?',
#    'ref': '01JBSTV8B30T32QTH0B30YVPNQ',
#    'properties': {'randomize': False,
#     'allow_multiple_selection': True,
#     'allow_other_choice': False,
#     'vertical_alignment': True,
#     'choices': [{'id': 'IzJ5qRN8LeVN',
#       'ref': '01JBSTV8B36M1K4828HG66Y1BV',
#       'label': 'full-time projects'},
#      {'id': 'PX077r8CsnAH',
#       'ref': '01JBSTV8B332PK30D9RTABH34K',
#       'label': 'hobby projects'},
#      {'id': 'EJA9LgfaZSRP',
#       'ref': '01JBSTV8B3Y5RGTAF6HDQ15KFX',
#       'label': "I don't use Sphinx"}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': '2Bul8ZafGFci',
#    'title': 'What markup language(s) are you using in your narrative documentation ?',
#    'ref': '01JBSTV8B3Y5SMN2XQC1JP7KYX',
#    'properties': {'randomize': False,
#     'allow_multiple_selection': True,
#     'allow_other_choice': True,
#     'vertical_alignment': True,
#     'choices': [{'id': 'cxs8kRb3C5Q8',
#       'ref': '01JBSTV8B3XET34N1HG2MY6CY9',
#       'label': 'Markdown'},
#      {'id': 'mk0tbnYxlNQC',
#       'ref': '01JBSTV8B3C1WFN7X7EADQ4C0H',
#       'label': 'RST'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': 'QEIn9n4s3jER',
#    'title': 'Do you write documentations in your native  language ?',
#    'ref': '01JBSTV8B3DQ93GJKAEMAXA7N5',
#    'properties': {'randomize': False,
#     'allow_multiple_selection': False,
#     'allow_other_choice': False,
#     'vertical_alignment': True,
#     'choices': [{'id': 'zo4FyBDolviz',
#       'ref': '01JBSTV8B3Z0EHBEF4M3A17P9R',
#       'label': 'Yes'},
#      {'id': '3mfYBtX3Utp8',
#       'ref': '01JBSTV8B3R1P0XQHBYP6JJE89',
#       'label': 'No'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': 'T1hpewy52QJV',
#    'title': 'Do you write documentatin in a foreign language ?',
#    'ref': '01JBSTV8B305SVDQJAM56X4XC9',
#    'properties': {'randomize': False,
#     'allow_multiple_selection': False,
#     'allow_other_choice': False,
#     'vertical_alignment': True,
#     'choices': [{'id': 'pGTp1Rdw1FAs',
#       'ref': '01JBSTV8B3N1XPVBXR80JVSG11',
#       'label': 'Yes'},
#      {'id': 'cXn6TjutM7wP',
#       'ref': '01JBSTV8B3BKJJQ7WXTGJBP0ZB',
#       'label': 'No'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': 'i7hRQbXi4uCS',
#    'title': 'In which Language(s) do you write your docs?',
#    'ref': '01JBSTV8B3FTRT000XZWGZDBZW',
#    'properties': {'description': 'We included some of the most spoken languages for convenience, please list other languages in the "other" field, comma separated',
#     'randomize': False,
#     'allow_multiple_selection': True,
#     'allow_other_choice': True,
#     'vertical_alignment': True,
#     'choices': [{'id': 'ZKZR5XswNvYQ',
#       'ref': '01JBSTV8B32FMKEDCVHV11YWRK',
#       'label': 'English'},
#      {'id': 'M6YebyHE3OSd',
#       'ref': '01JBSTV8B30KEMGBJG2TZ7RT4B',
#       'label': 'Mandarin Chinese'},
#      {'id': 'cajpQhNP8aLI',
#       'ref': '01JBSTV8B32FMKKTN0E714AXBM',
#       'label': 'Modern Standard Arabic'},
#      {'id': 'jAZpSqQPCbf4',
#       'ref': '01JBSTV8B34TJ499KFEV82QT8C',
#       'label': 'Hindi'},
#      {'id': 'TDky4xXevvYo',
#       'ref': '01JBSTV8B3Z3N3KCQTME7G5QG1',
#       'label': 'French'},
#      {'id': '7fK3ZEmV6huM',
#       'ref': '01JBSTV8B3200DQD272MRM4QX3',
#       'label': 'Spanish'},
#      {'id': '58KmdXM92UGP',
#       'ref': '01JBSTV8B3PPMS77H7PZH5G27K',
#       'label': 'Japanese'},
#      {'id': 'GYXZUQ1IGKfB',
#       'ref': '01JBSTV8B3JQRNB1PKJVT7NKT0',
#       'label': 'Bengali'},
#      {'id': 'aEuODxRsE146',
#       'ref': '01JBSTV8B36K80FX0N5AJAJGJA',
#       'label': 'Portugese'},
#      {'id': 'X572lxU4UpDZ',
#       'ref': '01JBSTV8B3435QCXQB4MHZE15T',
#       'label': 'Russian'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': 'wKkhEI3uAbrV',
#    'title': 'What are your professional role(s) in the project(s) which are using sphinx ?',
#    'ref': '01JBSTV8B3K81F8PM4VRJV2BHG',
#    'properties': {'randomize': False,
#     'allow_multiple_selection': True,
#     'allow_other_choice': True,
#     'vertical_alignment': True,
#     'choices': [{'id': 'FGju5CdMS9jF',
#       'ref': '01JBSTV8B3A43H95ZBZGYKTH7Z',
#       'label': 'Developer'},
#      {'id': '6K5Pmuap92Li',
#       'ref': '01JBSTV8B3ZJFGM7MQJTZ4DA0B',
#       'label': 'data scientist'},
#      {'id': 'csEgFQx2UpgV',
#       'ref': '01JBSTV8B3RWDEZPNK7Y97WAV4',
#       'label': 'Educator'},
#      {'id': 'DgcVl23zzm3Y',
#       'ref': '01JBSTV8B3GZ1B5J56BV75R4YT',
#       'label': 'technical writer'},
#      {'id': 'QKiO4MIN6gMK',
#       'ref': '01JBSTV8B3D1PB8XKSE4M1K6N3',
#       'label': 'community manager'},
#      {'id': 'jia2gYkxKulh',
#       'ref': '01JBSTV8B3RW8SH1ZQ20BSJQ16',
#       'label': 'testing engineer'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': 'jqIsRxMdLQjU',
#    'title': 'In which Python ecosystem do you fit better',
#    'ref': '01JBSTV8B3AFR56TFC7811T688',
#    'properties': {'randomize': False,
#     'allow_multiple_selection': False,
#     'allow_other_choice': False,
#     'vertical_alignment': True,
#     'choices': [{'id': 'WaYgDPwTHKhj',
#       'ref': '01JBSTV8B3W87A162XCYMYYZ3P',
#       'label': 'DataScience'},
#      {'id': 'q8KI66jKdytt',
#       'ref': '01JBSTV8B32QFH4SMRQZ9W3W5N',
#       'label': 'Web'},
#      {'id': 'GT5XU0R5SGds',
#       'ref': '01JBSTV8B3DA5TCQ0YMZTZTJ57',
#       'label': 'Scientific Python'},
#      {'id': 's1tdGCQ7GPIY',
#       'ref': '01JBSTV8B3GD9K7W9AN1ET6G1R',
#       'label': 'infrastructure'},
#      {'id': 'Rt0vKucvFLNU',
#       'ref': '01JBSTV8B3ZG36KM2D6G7WYAAD',
#       'label': 'Other (precise)'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': 'K0qE3RfbIwHs',
#    'title': 'The following section is about sphinx specifically.',
#    'ref': '01JBSTV8B3F6Y91AK5HVJJSWWM',
#    'properties': {'button_text': 'Continue', 'hide_marks': False},
#    'type': 'statement'},
#   {'id': 'OQiOwhFtlR6k',
#    'title': 'What theme(s) do you use with sphinx?',
#    'ref': '01JBSTV8B3KGGJN0YNQPAJ1YQ4',
#    'properties': {'description': 'Comma separated list in other if relevant.',
#     'randomize': False,
#     'allow_multiple_selection': True,
#     'allow_other_choice': True,
#     'vertical_alignment': True,
#     'choices': [{'id': 'NMjXfK6FmAVq',
#       'ref': '01JBSTV8B3EQ704YX3KY7N06HB',
#       'label': 'Whatever comes with sphinx by default'},
#      {'id': '4SJe9w9xTvQQ',
#       'ref': '01JBSTV8B3NMSQBZ5Q1VJBYXFT',
#       'label': 'Alabaster'},
#      {'id': 'WkCU8W7WgRb3',
#       'ref': '01JBSTV8B3SQFKZC76YYR6H11V',
#       'label': 'Readthedocs'},
#      {'id': '5iCoC7ONcvXv',
#       'ref': '01JBSTV8B3ASGS5E8N0TYJ2ZV6',
#       'label': 'Pydata Sphinx Theme'},
#      {'id': 'f6W9mXp8qCJx',
#       'ref': '01JBSTV8B3BYD08XSQW2DWNDXJ',
#       'label': 'Material design'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': 'sPmA6QKkbOIl',
#    'title': 'What extensions do you use with sphinx >',
#    'ref': '01JBSTV8B3JJ227E8Q3SGTNRS3',
#    'properties': {'description': 'List comma seprated extension in other if relevant',
#     'randomize': False,
#     'allow_multiple_selection': True,
#     'allow_other_choice': False,
#     'vertical_alignment': True,
#     'choices': [{'id': 'idJteHuy6Lm5',
#       'ref': '01JBSTV8B3R9GKP0G2N1EDTAD3',
#       'label': 'numpydoc'},
#      {'id': 'Gw7NfcKDco5T',
#       'ref': '01JBSTV8B3T67ZZESQWBXK9F9Y',
#       'label': 'autodoc'},
#      {'id': 'NAnpQbDuGG6x',
#       'ref': '01JBSTV8B3V5RBT07QV7TQQMJ4',
#       'label': 'intersphinx'},
#      {'id': 'CHzhgg1lEFFa',
#       'ref': '01JBSTV8B3A7Q2Y8NT1JNXZZW5',
#       'label': 'mathjax'},
#      {'id': 'UuFVNA7jLLc8',
#       'ref': '01JBSTV8B3C46D23EB3XBPGMPB',
#       'label': 'ifconfig'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': '6tfK5IfrKWYV',
#    'title': 'Rate your issues with sphinx concerning *RST*',
#    'ref': '01JBSTV8B3018ASHV7FNYY1WRX',
#    'properties': {'description': 'RST syntax is too complicated',
#     'start_at_one': False,
#     'steps': 11,
#     'labels': {'left': 'syntax is great',
#      'center': 'Just right',
#      'right': 'syntax is too complicated'}},
#    'validations': {'required': False},
#    'type': 'opinion_scale'},
#   {'id': 'XNtlNNfK8OOf',
#    'title': 'Rate your issues with sphinx concerning *missing features*',
#    'ref': '01JBSTV8B3DSYTABYZ3GFAK0M2',
#    'properties': {'description': 'Sphinx is missing features',
#     'start_at_one': False,
#     'steps': 11,
#     'labels': {'left': 'I have all the features I need',
#      'right': 'Too many things are missing'}},
#    'validations': {'required': False},
#    'type': 'opinion_scale'},
#   {'id': 'vOapawypTqXI',
#    'title': 'Rate your issues with sphinx concerning *Performances*',
#    'ref': '01JBSTV8B39WK2P9VBDKKEX5MR',
#    'properties': {'description': 'Sphinx is not fast enough, or use too much resources',
#     'start_at_one': False,
#     'steps': 11,
#     'labels': {'left': 'Sphinx is fast for my project',
#      'right': 'Sphinx is way too slow.'}},
#    'validations': {'required': False},
#    'type': 'opinion_scale'},
#   {'id': 'kMSEd6lKgDeN',
#    'title': 'Rate your issues with sphinx concerning *Stability*',
#    'ref': '01JBSTV8B3RTYNJHY6TX3B1ADD',
#    'properties': {'description': 'Sphinx API changes too often/too many bugs',
#     'start_at_one': False,
#     'steps': 11,
#     'labels': {'left': 'Sphinx is stable',
#      'right': 'Sphinx breaks/changes too often.'}},
#    'validations': {'required': False},
#    'type': 'opinion_scale'},
#   {'id': 'D6ksUTrP3j2y',
#    'title': 'Rate your issues with sphinx concerning *Sphinx itself*',
#    'ref': '01JBSTV8B35V07PQ3ARC392PVX',
#    'properties': {'description': 'Sphinx is too complex to use',
#     'start_at_one': False,
#     'steps': 11,
#     'labels': {'left': 'Sphinx is easy to use/configure and works out of the box.',
#      'right': 'Sooo complicated.'}},
#    'validations': {'required': False},
#    'type': 'opinion_scale'},
#   {'id': 'Df6prejYfoOw',
#    'title': 'Are you missing anything from sphinx >',
#    'ref': '01JBSTV8B3FBCJCKSAPQ97CXZD',
#    'validations': {'required': False},
#    'type': 'long_text'},
#   {'id': 'opkZZsFIQyIC',
#    'title': 'What output formats do you use the most?',
#    'ref': '01JBSTV8B3FCQPFMG59FH1645A',
#    'properties': {'randomize': False,
#     'allow_multiple_selection': True,
#     'allow_other_choice': True,
#     'vertical_alignment': True,
#     'choices': [{'id': 'A4sGn3AmWCJN',
#       'ref': '01JBSTV8B3RTXWZ1BPF04EC8VZ',
#       'label': 'Html'},
#      {'id': 'JL6ifgtmB6X0',
#       'ref': '01JBSTV8B3F2JDG1S2WRCRXZDJ',
#       'label': 'Pdf'},
#      {'id': 'uLFP6TOYXV1j',
#       'ref': '01JBSTV8B3FYSQSWDJ2VYYKYM1',
#       'label': 'Epub'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': 'y9bZ09hb18mc',
#    'title': 'What output formats do you do without?',
#    'ref': '01JBSTV8B38VN8KPJQQX2EQ8JR',
#    'properties': {'randomize': False,
#     'allow_multiple_selection': True,
#     'allow_other_choice': True,
#     'vertical_alignment': True,
#     'choices': [{'id': 'zLTz92CxnAQA',
#       'ref': '01JBSTV8B35E2202YJ3DJ4FV1H',
#       'label': 'Html'},
#      {'id': 'v1x1e68OzECH',
#       'ref': '01JBSTV8B3MMFWAHE4YQ89T099',
#       'label': 'Pdf'},
#      {'id': 'q925mfwNpcBG',
#       'ref': '01JBSTV8B3BCB9FDJC2GRBBF5Y',
#       'label': 'Epub'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'}],
#  '_links': {'display': 'https://s3mu8c5idqn.typeform.com/to/Oq55zKog',
#   'responses': 'https://api.typeform.com/forms/Oq55zKog/responses'}}
