# %%
from os import environ

# %%
token = environ.get('TYPEFORM_TOKEN')

# %%
from typeform import Typeform

# %%
typeform = Typeform(token)

# %%
# Create a form by hand and get the 'id'
#res = typeform.forms.create({'title':'Sphinx Survey II', 'fields':
#    []
#})
#res

# %%
import yaml
with open('survey.yml') as f:
    res = yaml.safe_load(f.read())

# %%
typeform.forms.get('Oq55zKog')['fields'][20]
# Out:
# {'id': 'f6b49OUh0QbF',
#  'title': 'Feedback',
#  'ref': '65b9ab09-fcd5-4859-b7fe-d103c10d7afc',
#  'properties': {},
#  'validations': {'required': False},
#  'type': 'long_text'}

# %%
with open('survey.yml') as f:
    res = yaml.safe_load(f.read())
questions = []
from copy import deepcopy
for yqu in deepcopy(res):
    q = {}
    q['title'] = yqu.pop('title')
    prop = {}
    if 'description' in yqu:
            prop['description'] = yqu.pop('description')
    if 'choices' in yqu:
        q['type'] = 'multiple_choice'
        
        
        q['properties']=prop
        if yqu.pop('multiple', False):
            prop['allow_multiple_selection'] = True
        if yqu.pop('other', False):
            prop['allow_other_choice'] = True
        prop['choices'] = []
        choices = yqu.pop('choices')
        for c in choices:
            prop['choices'].append({'label':c})
    elif 'type' in yqu and yqu['type'] in ('number', 'statement'):
        q['type'] = yqu.pop('type')
        q['properties'] = prop
    elif yqu['type'] == 'opinion_scale':
        q['type'] = yqu.pop('type')
        if 'start' in yqu:
            start = yqu.pop('start') 
            assert start in (1, 0)
            if start == 1:
                prop['start_at_one'] = True
            if start == 0:
                pass # the default.
        prop['steps'] = yqu.pop('steps', 11)
        if 'labels' in yqu:
            labels = yqu.pop('labels')
            assert len(labels) in [2,3]
            if len(labels) == 2:    
                prop['labels']={'left': labels[0], 'right': labels[1]}
            if len(labels) == 3:    
                prop['labels']={'left': labels[0], 'middle':labels[1],'right': labels[2]}    
        q['properties'] = prop
    elif yqu['type'] == 'long_text':
        q['type'] = yqu.pop('type')
        # nothing to do
        
    assert not yqu, yqu
    questions.append(q)

typeform.forms.update('Oq55zKog',{'title':'Sphinx Survey oct 17', 'fields':
   questions

})
# Out:
# {'id': 'Oq55zKog',
#  'type': 'quiz',
#  'title': 'Sphinx Survey oct 17',
#  'workspace': {'href': 'https://api.typeform.com/workspaces/wDgMRr'},
#  'theme': {'href': 'https://api.typeform.com/themes/qHWOQ7'},
#  'settings': {'language': 'en',
#   'progress_bar': 'proportion',
#   'meta': {'allow_indexing': False},
#   'hide_navigation': False,
#   'is_public': True,
#   'is_trial': False,
#   'show_progress_bar': True,
#   'show_typeform_branding': True,
#   'are_uploads_public': False,
#   'show_time_to_complete': True,
#   'show_number_of_submissions': False,
#   'show_cookie_consent': False,
#   'show_question_number': True,
#   'show_key_hint_on_choices': True,
#   'autosave_progress': True,
#   'free_form_navigation': False,
#   'use_lead_qualification': False,
#   'pro_subdomain_enabled': False},
#  'thankyou_screens': [{'id': 'DefaultTyScreen',
#    'ref': 'default_tys',
#    'title': "Thanks for completing this typeform\nNow *create your own* — it's free, easy, & beautiful",
#    'type': 'thankyou_screen',
#    'properties': {'show_button': True,
#     'share_icons': False,
#     'button_mode': 'default_redirect',
#     'button_text': 'Create a *typeform*'},
#    'attachment': {'type': 'image',
#     'href': 'https://images.typeform.com/images/2dpnUBBkz2VN'}}],
#  'fields': [{'id': 'n2LsFHsCaLmc',
#    'title': 'Sphinx Usage survey 2024',
#    'ref': '01JBRSG7XD7B00YB592QCGT740',
#    'properties': {'description': "This is the sphinx usage survey for 2024, we'd like to understand the main reason you do (not) use sphinx.\nYou can help us improve this survey by submitting a PR to the file that deinfe this survey on GitHub <URL>.\nAnd will be able to find the result in the repository at a later date.\n",
#     'button_text': 'Continue',
#     'hide_marks': False},
#    'type': 'statement'},
#   {'id': 'rpQopCLDWeZN',
#    'title': 'What is your age range',
#    'ref': '01JBRSG7XDBV1RFZT7JCKXT1F1',
#    'properties': {'randomize': False,
#     'allow_multiple_selection': False,
#     'allow_other_choice': False,
#     'vertical_alignment': True,
#     'choices': [{'id': 'AIWRlPBgAD6U',
#       'ref': '01JBRSG7XDP14QKBVHZATQRDKF',
#       'label': '<15'},
#      {'id': 'Qwm2EmB1uogk',
#       'ref': '01JBRSG7XDAEC6N6BF7R8YR53P',
#       'label': '15-25'},
#      {'id': 'sEyw2RlPPZ6z',
#       'ref': '01JBRSG7XDY9EE5VPE1BJJ6D02',
#       'label': '26-35'},
#      {'id': 'PYKeXt4lB4oN',
#       'ref': '01JBRSG7XDR4PC6XQSHXN2V3KZ',
#       'label': '36-45'},
#      {'id': 'v5RV6FPeQ6Qk',
#       'ref': '01JBRSG7XDWD0TGAZ1RCSSZT2M',
#       'label': '45-55'},
#      {'id': 'Ad0E0DLb2S21',
#       'ref': '01JBRSG7XD0DJW2EW77K3HCTZD',
#       'label': '56-65'},
#      {'id': 'FOJz1luvAd32',
#       'ref': '01JBRSG7XDGZQJPHM4WYQNG8S6',
#       'label': '65+'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': 'ETybAgoi20gS',
#    'title': 'Which gender do you indentify as',
#    'ref': '01JBRSG7XDTSBBGA8HF00YRHJG',
#    'properties': {'description': 'You can edit the value in Other.',
#     'randomize': False,
#     'allow_multiple_selection': False,
#     'allow_other_choice': True,
#     'vertical_alignment': True,
#     'choices': [{'id': 'Kp6WafgkOgQ1',
#       'ref': '01JBRSG7XD184842K0Y91AZ2R1',
#       'label': 'Male'},
#      {'id': 'FcxOgO5cNHPG',
#       'ref': '01JBRSG7XD2RP74QDDGS1PND4Y',
#       'label': 'Female'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': 'PoRASFkopdcZ',
#    'title': 'Do you consider youself as working as part of a team or independant ?',
#    'ref': '01JBRSG7XDAXATSESFMRSB45MY',
#    'properties': {'description': 'You can select both if both apply',
#     'randomize': False,
#     'allow_multiple_selection': True,
#     'allow_other_choice': False,
#     'vertical_alignment': True,
#     'choices': [{'id': 'T5VNY9yH5OxQ',
#       'ref': '01JBRSG7XD9ZFWA0Q9QEQBCDRP',
#       'label': 'Part of team'},
#      {'id': '3ZfgPPJFbdqW',
#       'ref': '01JBRSG7XDW2QR9YQGT8A1ZYBA',
#       'label': 'Independant'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': 'e1HzD4UNBTkT',
#    'title': 'Do you consider yourself full-time or hobbyist?',
#    'ref': '01JBRSG7XD2VCGNNGWKA1B4TSR',
#    'properties': {'description': 'That is to say do you mainly code in Python, or one a few hours here and there ?',
#     'randomize': False,
#     'allow_multiple_selection': False,
#     'allow_other_choice': False,
#     'vertical_alignment': True,
#     'choices': [{'id': '8qUPoG2zFixe',
#       'ref': '01JBRSG7XDD8ANTJYFV442N054',
#       'label': 'full-time'},
#      {'id': '7z5e3mvCGyLu',
#       'ref': '01JBRSG7XDN3XRHSMB898T6SX4',
#       'label': 'hobbyist'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': '0MZoTK3M2iD9',
#    'title': 'In whcih context do you use sphinx',
#    'ref': '01JBRSG7XD3ES18B18SQJ0NC31',
#    'properties': {'randomize': False,
#     'allow_multiple_selection': True,
#     'allow_other_choice': False,
#     'vertical_alignment': True,
#     'choices': [{'id': 'fGSUYrpvLMLp',
#       'ref': '01JBRSG7XDY9JVEKHAHAZEMD8V',
#       'label': 'full-time projects'},
#      {'id': 'xJGvk8SIXn0x',
#       'ref': '01JBRSG7XD87CQTFXNJBMVTWJ7',
#       'label': 'hobby projects'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': '9WVHGIFY3kYM',
#    'title': 'How many year of Python experience you have',
#    'ref': '01JBRSG7XD5DF077K4DSCXWKMW',
#    'properties': {},
#    'validations': {'required': False},
#    'type': 'number'},
#   {'id': 'BoSBtzyVuEcK',
#    'title': 'What documentation engines do you use?',
#    'ref': '01JBRSG7XD7YDS5K1EB41AM12C',
#    'properties': {'description': 'You can select multiple options, if you also select other, please specifiy as a comma separated list. ',
#     'randomize': False,
#     'allow_multiple_selection': True,
#     'allow_other_choice': True,
#     'vertical_alignment': True,
#     'choices': [{'id': 'dxgdohq03FJa',
#       'ref': '01JBRSG7XD2KS9RBMS4PBZ6D64',
#       'label': 'MyST'},
#      {'id': 'OU54D7Raqcxp',
#       'ref': '01JBRSG7XDN2GME8DAVXFXJK3X',
#       'label': 'Docusaurus'},
#      {'id': '7sDI7TfaHf1n',
#       'ref': '01JBRSG7XDWAA6PN08VPETAH46',
#       'label': 'Mkdocs'},
#      {'id': 'iKwyRi5xVvL8',
#       'ref': '01JBRSG7XDA10QXR79GG4PSDKH',
#       'label': 'JupyterBook'},
#      {'id': 'Lr8A6xp7JWOi',
#       'ref': '01JBRSG7XDD1NZCVECT8P8GEQD',
#       'label': 'Sphinx'},
#      {'id': 'ySXrofnLHfBO',
#       'ref': '01JBRSG7XDN7J8Q486RTD78Q77',
#       'label': 'None'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': 'dbgg2b6wAL94',
#    'title': 'What markup language are you using in your narrative documentation?',
#    'ref': '01JBRSG7XD2PD73EWVCVDPKJT4',
#    'properties': {'randomize': False,
#     'allow_multiple_selection': True,
#     'allow_other_choice': True,
#     'vertical_alignment': True,
#     'choices': [{'id': '8BkLOYZCLyC3',
#       'ref': '01JBRSG7XDZHQXFFW2S4K968FR',
#       'label': 'Markdown'},
#      {'id': 'cItXzCMsmeUk',
#       'ref': '01JBRSG7XD658T0B7DKZV8YHBR',
#       'label': 'RST'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': 'uCK2TgYMgWff',
#    'title': 'Do you write documentations in your native native language ?',
#    'ref': '01JBRSG7XDTHAZN21BC7P0TNPK',
#    'properties': {'randomize': False,
#     'allow_multiple_selection': False,
#     'allow_other_choice': False,
#     'vertical_alignment': True,
#     'choices': [{'id': 'U0bXV4vmzFco',
#       'ref': '01JBRSG7XDBETMJEJAFBMZ8D80',
#       'label': 'Yes'},
#      {'id': 'RQP9CVtuavzv',
#       'ref': '01JBRSG7XDA3YY825ZCSNBPCEP',
#       'label': 'No'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': 'ZpBCBHg2Kqi8',
#    'title': 'Do you write documentatin in a foreing language ?',
#    'ref': '01JBRSG7XD91SBGVY3RRBX0YC0',
#    'properties': {'randomize': False,
#     'allow_multiple_selection': False,
#     'allow_other_choice': False,
#     'vertical_alignment': True,
#     'choices': [{'id': '7F0NZv6tNdqV',
#       'ref': '01JBRSG7XDFH7WY1RANGS0P22F',
#       'label': 'Yes'},
#      {'id': '9JCaUvT4O3Hq',
#       'ref': '01JBRSG7XD5A3G9BF5P313NZJX',
#       'label': 'No'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': 'c5Qwkaxfwisr',
#    'title': 'In which Language do you write your docs?',
#    'ref': '01JBRSG7XDHKX1XV4GE251RDPK',
#    'properties': {'randomize': False,
#     'allow_multiple_selection': True,
#     'allow_other_choice': True,
#     'vertical_alignment': True,
#     'choices': [{'id': 'ug2W6OREMUvb',
#       'ref': '01JBRSG7XDB7Z6M12QTP1TBQRA',
#       'label': 'English'},
#      {'id': '3SLJmb72KY1Q',
#       'ref': '01JBRSG7XDK3XD4KE864C9CYSA',
#       'label': 'French'},
#      {'id': '2oMNz47V5S8h',
#       'ref': '01JBRSG7XDQMSFZPA7SBXRAASS',
#       'label': 'Spanish'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': 'K2zrtspONnkX',
#    'title': 'What are your professional role/role in the project(s) that are using sphinx ?',
#    'ref': '01JBRSG7XDS114TKE3J17A3F21',
#    'properties': {'randomize': False,
#     'allow_multiple_selection': False,
#     'allow_other_choice': True,
#     'vertical_alignment': True,
#     'choices': [{'id': 'AIHXlBtHC4rr',
#       'ref': '01JBRSG7XDJS7S6PWQNYCDDT0Z',
#       'label': 'Developer'},
#      {'id': '6inCb3bpyw64',
#       'ref': '01JBRSG7XD441Y1A9FBZXZ7DB1',
#       'label': 'data scientist'},
#      {'id': 'l86jGrMoKD3j',
#       'ref': '01JBRSG7XD014PG8X6WBN8S4FC',
#       'label': 'Educator'},
#      {'id': 'eQGQ8wsMM7aT',
#       'ref': '01JBRSG7XDC68NSVQVK1FE2XNR',
#       'label': 'technical writer'},
#      {'id': '07htf1e2xioc',
#       'ref': '01JBRSG7XDWGVWGK728T4NKQVM',
#       'label': 'community manager'},
#      {'id': 'yBbwC3Nv5h1N',
#       'ref': '01JBRSG7XDFARVR0H7FCE3YR3V',
#       'label': 'testing engineer'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': 'VbmfnTXiceIQ',
#    'title': 'In which Python ecosystem do you fit better',
#    'ref': '01JBRSG7XD2M7MKHAMZE75ZK97',
#    'properties': {'randomize': False,
#     'allow_multiple_selection': False,
#     'allow_other_choice': False,
#     'vertical_alignment': True,
#     'choices': [{'id': 'UhcBFrPwCadn',
#       'ref': '01JBRSG7XD2XEM2VNYWJ7FTZXG',
#       'label': 'DataScience'},
#      {'id': 'YtMtA0n1tsTs',
#       'ref': '01JBRSG7XD6ZC1S79BCWNHW93V',
#       'label': 'Web'},
#      {'id': 'nKsqXQ7nzAQe',
#       'ref': '01JBRSG7XDVEJP7QRS4W35MQV5',
#       'label': 'Scientific Python'},
#      {'id': 'ZCbYuXEtViRI',
#       'ref': '01JBRSG7XDQZAENFYA27SQBKQ4',
#       'label': 'infrastructure'},
#      {'id': 'TviIoN5tLas9',
#       'ref': '01JBRSG7XD9Z0CWT13Y191SHH0',
#       'label': 'Other (precise)'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': 'hqNz1Mv5mBu6',
#    'title': 'What theme(s) do you use?',
#    'ref': '01JBRSG7XD8VTXGMZPA5Z671WQ',
#    'properties': {'description': 'comma separated list in other if relevant.',
#     'randomize': False,
#     'allow_multiple_selection': True,
#     'allow_other_choice': True,
#     'vertical_alignment': True,
#     'choices': [{'id': 'ZT3ZDIhqjTQr',
#       'ref': '01JBRSG7XDNNS6GE9SCC0MGJ2K',
#       'label': 'Whatever comes with sphinx by default'},
#      {'id': 'yhlXJBAuRV3h',
#       'ref': '01JBRSG7XDNXQ39FQ57BKES24T',
#       'label': 'Alabaster'},
#      {'id': 'weUgtCN1DNpr',
#       'ref': '01JBRSG7XDQP22T14E4ZV06TMT',
#       'label': 'Readthedocs'},
#      {'id': 'Nr5lPsX7ktoR',
#       'ref': '01JBRSG7XDKQNCVPH0AB5TDZHD',
#       'label': 'Pydata Sphinx There'},
#      {'id': 'kxtZcnga3zfq',
#       'ref': '01JBRSG7XE5BZ2EZ0GQ2AFVE3F',
#       'label': 'Material design'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': 'gk2ZtUrtedcT',
#    'title': 'Rate your issues with sphinx concerning *RST*',
#    'ref': '01JBRSG7XEXX95WWXQRRNQE0VR',
#    'properties': {'description': 'RST syntax is too complicated',
#     'start_at_one': False,
#     'steps': 11,
#     'labels': {'left': 'syntax is ok', 'right': 'syntax is too complicated'}},
#    'validations': {'required': False},
#    'type': 'opinion_scale'},
#   {'id': 'oGiBUbXUfl5B',
#    'title': 'Rate your issues with sphinx concerning *missing features*',
#    'ref': '01JBRSG7XEE65ZTES8B76T3KS9',
#    'properties': {'description': 'Sphinx is missing features',
#     'start_at_one': False,
#     'steps': 11,
#     'labels': {'left': 'I have all the features I need',
#      'right': 'Too many things are missing'}},
#    'validations': {'required': False},
#    'type': 'opinion_scale'},
#   {'id': 'NL4sEqj6rIk1',
#    'title': 'Rate your issues with sphinx concerning *Performances*',
#    'ref': '01JBRSG7XEMVJMT6T2JM82N0EQ',
#    'properties': {'description': 'Sphinx is not fast enough, or use too much resources',
#     'start_at_one': False,
#     'steps': 11,
#     'labels': {'left': 'Sphinx is fast for my project',
#      'right': 'Sphinx is way too slow.'}},
#    'validations': {'required': False},
#    'type': 'opinion_scale'},
#   {'id': 'yRfvske0w5Ot',
#    'title': 'Rate your issues with sphinx concerning *Stability*',
#    'ref': '01JBRSG7XE30MG4AHKNA77QKC7',
#    'properties': {'description': 'Sphinx API changes too often/too many bugs',
#     'start_at_one': False,
#     'steps': 11,
#     'labels': {'left': 'Sphinx is stable',
#      'right': 'Sphinx breaks/changes too often.'}},
#    'validations': {'required': False},
#    'type': 'opinion_scale'},
#   {'id': 'bTzud6NLLBr9',
#    'title': 'Rate your issues with sphinx concerning *Sphinx itself*',
#    'ref': '01JBRSG7XECRMW7MG8AB69JEQD',
#    'properties': {'description': 'Sphinx is too complex to use',
#     'start_at_one': False,
#     'steps': 11,
#     'labels': {'left': 'Sphinx is easy to use/configure and works out of the box.',
#      'right': 'Sooo complicated.'}},
#    'validations': {'required': False},
#    'type': 'opinion_scale'},
#   {'id': 'OqC1WxiAvCtm',
#    'title': 'What output formats do you use the most?',
#    'ref': '01JBRSG7XEZ4P42Y0QNZ81KB77',
#    'properties': {'randomize': False,
#     'allow_multiple_selection': True,
#     'allow_other_choice': True,
#     'vertical_alignment': True,
#     'choices': [{'id': 'wRUzy3RnRtSZ',
#       'ref': '01JBRSG7XEXW76FEF9XMK37TFP',
#       'label': 'Html'},
#      {'id': 'kVujsA0RxMAh',
#       'ref': '01JBRSG7XEBGYXRZ2NVH5K5NSW',
#       'label': 'Pdf'},
#      {'id': '5DpnV6DyS2qn',
#       'ref': '01JBRSG7XE9QH4HGD9TCFZ6FCD',
#       'label': 'Epub'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': 'uUGzkE0gtnVd',
#    'title': 'What output formats do you do without?',
#    'ref': '01JBRSG7XEQRXV055MTVT0JAVN',
#    'properties': {'randomize': False,
#     'allow_multiple_selection': True,
#     'allow_other_choice': True,
#     'vertical_alignment': True,
#     'choices': [{'id': 'jD3Wj4ll1lBK',
#       'ref': '01JBRSG7XET8HV4ESVBF7WMK9T',
#       'label': 'Html'},
#      {'id': 'QmEXBOXc00vz',
#       'ref': '01JBRSG7XETGYFZGBVRW0YJ754',
#       'label': 'Pdf'},
#      {'id': 'alMgTRt5d9bf',
#       'ref': '01JBRSG7XE8Z960V6VEJ6SFFCK',
#       'label': 'Epub'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'}],
#  '_links': {'display': 'https://s3mu8c5idqn.typeform.com/to/Oq55zKog',
#   'responses': 'https://api.typeform.com/forms/Oq55zKog/responses'}}
