# %%
from os import environ
from typeform import Typeform
import yaml
from copy import deepcopy

# %%
token = environ.get('TYPEFORM_TOKEN')

# %%
typeform = Typeform(token)

# %%
with open('sphinx-survey.yml') as f:
    res = yaml.safe_load(f.read())
questions = []


for yqu in deepcopy(res):
    q = {}
    if 'type' not in yqu:
        assert 'choices' in yqu, yqu
    q['title'] = yqu.pop('title')
    prop = {}
    if 'description' in yqu:
            prop['description'] = yqu.pop('description')

    if 'choices' in yqu and yqu.get('type', None) in ('multiple_choices',None):
        q['type'] = 'multiple_choice'
        
        
        q['properties']=prop
        if yqu.pop('multiple', False):
            prop['allow_multiple_selection'] = True
        if yqu.pop('other', False):
            prop['allow_other_choice'] = True
        prop['choices'] = []
        choices = yqu.pop('choices')
        for c in choices:
            if c.strip().startswith('::'):
                assert c == '::other_please_type::'
                prop['allow_other_choice'] = True
                continue
            prop['choices'].append({'label':c})
    elif 'type' in yqu and yqu['type'] in ('number', 'statement'):
        q['type'] = yqu.pop('type')
        q['properties'] = prop
    elif yqu['type'] == 'opinion_scale':
        q['type'] = yqu.pop('type')
        if 'start' in yqu:
            start = yqu.pop('start') 
            assert start in (1, 0)
            if start == 1:
                prop['start_at_one'] = True
            if start == 0:
                pass # the default.
        prop['steps'] = yqu.pop('steps', 11)
        if 'labels' in yqu:
            labels = yqu.pop('labels')
            assert len(labels) in [2,3]
            if len(labels) == 2:    
                prop['labels']={'left': labels[0], 'right': labels[1]}
            elif len(labels) == 3:    
                prop['labels']={'left': labels[0], 'center':labels[1],'right': labels[2]}    
                print(prop)
            else:
                assert False
        q['properties'] = prop
    elif yqu['type'] == 'long_text':
        q['type'] = yqu.pop('type')
        # nothing to do
    elif yqu['type'] == 'ranking':
        
        q['type'] = yqu.pop('type')
        choices = yqu.pop('choices')
        prop['choices'] = []
        q['properties']=prop
        for c in choices:
            prop['choices'].append({'label':c})
    else:
        assert False, q 
    assert not yqu, yqu
    questions.append(q)

typeform.forms.update('Oq55zKog',{'title':'Sphinx Survey oct 17', 'fields':
   questions

})
# Out:
# {'id': 'Oq55zKog',
#  'type': 'quiz',
#  'title': 'Sphinx Survey oct 17',
#  'workspace': {'href': 'https://api.typeform.com/workspaces/wDgMRr'},
#  'theme': {'href': 'https://api.typeform.com/themes/qHWOQ7'},
#  'settings': {'language': 'en',
#   'progress_bar': 'proportion',
#   'meta': {'allow_indexing': False},
#   'hide_navigation': False,
#   'is_public': True,
#   'is_trial': False,
#   'show_progress_bar': True,
#   'show_typeform_branding': True,
#   'are_uploads_public': False,
#   'show_time_to_complete': True,
#   'show_number_of_submissions': False,
#   'show_cookie_consent': False,
#   'show_question_number': True,
#   'show_key_hint_on_choices': True,
#   'autosave_progress': True,
#   'free_form_navigation': False,
#   'use_lead_qualification': False,
#   'pro_subdomain_enabled': False},
#  'thankyou_screens': [{'id': 'DefaultTyScreen',
#    'ref': 'default_tys',
#    'title': "Thanks for completing this typeform\nNow *create your own* — it's free, easy, & beautiful",
#    'type': 'thankyou_screen',
#    'properties': {'show_button': True,
#     'share_icons': False,
#     'button_mode': 'default_redirect',
#     'button_text': 'Create a *typeform*'},
#    'attachment': {'type': 'image',
#     'href': 'https://images.typeform.com/images/2dpnUBBkz2VN'}}],
#  'fields': [{'id': 'sFr155HiWZNo',
#    'title': 'Sphinx Usage Survey 2025',
#    'ref': '01JJ97XZS5QBX8FDAVCMBQVC2V',
#    'properties': {'description': 'Sphinx Documentation User Survey 2025\n\nHelp the Sphinx community understand who is using Sphinx, how they are using it, and how well it supports the people using it. We will use this information to aid community discussion about improvements to Sphinx.\n\nResults will be public with identifying information removed. Open text field questions may be quoted, but will not be shown in full. \n\nThis survey is run by the Sphinx community; survey data will be deleted from any private accounts once made public. If you have any questions, reach out to _____.\n',
#     'button_text': 'Continue',
#     'hide_marks': False},
#    'type': 'statement'},
#   {'id': 'j31qZQCfIclm',
#    'title': 'Tell us about you',
#    'ref': '01JJ97XZS54KX633D95P0ADH05',
#    'properties': {'description': "First, we'd like to know about how you work and what tools you use.",
#     'button_text': 'Continue',
#     'hide_marks': False},
#    'type': 'statement'},
#   {'id': 'G4SnB8cJYw5i',
#    'title': 'Which of the following roles is closest to your job?',
#    'ref': '01JJ97XZS5197MJQ1MGD08KMVN',
#    'properties': {'randomize': False,
#     'allow_multiple_selection': False,
#     'allow_other_choice': False,
#     'vertical_alignment': True,
#     'choices': [{'id': 'SyIVhzfkclSb',
#       'ref': '01JJ97XZS5WW9DPQ5WQJBWZKS0',
#       'label': 'Academic researcher'},
#      {'id': 'u4LizS9GtomF',
#       'ref': '01JJ97XZS5E5J7MCS2QHHB7M18',
#       'label': 'Data scientist'},
#      {'id': 'TUjpTp7Fiqjn',
#       'ref': '01JJ97XZS5REBRFPPCRW1SXWGQ',
#       'label': 'Developer / Programmer'},
#      {'id': 'OPFGafueDzej',
#       'ref': '01JJ97XZS5G6490TVZR6Y7DYQK',
#       'label': 'ML engineer / MLOps'},
#      {'id': 'uoFO6Rvjy6Rf',
#       'ref': '01JJ97XZS5JKP2BS3B2CCX1MYD',
#       'label': 'Product manager'},
#      {'id': 'L1ena7BwTvcA',
#       'ref': '01JJ97XZS59Y5CDKQ90K2D57B8',
#       'label': 'QA engineer'},
#      {'id': 'vvCWoolzVMUq',
#       'ref': '01JJ97XZS58D7P0F70P500Z92G',
#       'label': 'Technical support'},
#      {'id': 'caYug4LqNSGr',
#       'ref': '01JJ97XZS5VHY17AY6X3X081VF',
#       'label': 'Technical writer'},
#      {'id': 'T5mVfb88lLky',
#       'ref': '01JJ97XZS5J7AP2VYG8SSFW257',
#       'label': 'Prefer not to answer'},
#      {'id': '3rls3W3VitGc',
#       'ref': '01JJ97XZS5AAG20278RZAC877D',
#       'label': 'Other'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': 'tCm6imyQU3Lg',
#    'title': 'Do you most often work on a team or independently?',
#    'ref': '01JJ97XZS5TH2PGNJB2TC3BKBA',
#    'properties': {'randomize': False,
#     'allow_multiple_selection': False,
#     'allow_other_choice': False,
#     'vertical_alignment': True,
#     'choices': [{'id': 'Y0DYkQxG29AQ',
#       'ref': '01JJ97XZS57NTWFCCBPNEQJ7F7',
#       'label': 'I most often work on projects independently'},
#      {'id': 'urqCxjqPsNu3',
#       'ref': '01JJ97XZS5M47P5AHR14ZKGGQK',
#       'label': 'I most often work on projects as part of a team'},
#      {'id': 'kLWQLPuGUyF2',
#       'ref': '01JJ97XZS5E2CCC4E1NYVEGARM',
#       'label': 'I spend about equal time working on projects independently as I do on a team'},
#      {'id': 'IV4zDSrIj79f',
#       'ref': '01JJ97XZS55002MVTRS560YV7X',
#       'label': 'Prefer not to answer'},
#      {'id': '4DXys7TwpvqS',
#       'ref': '01JJ97XZS5MS2JVN48S7ZQT0GQ',
#       'label': 'Other'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': 'DceO8SSoX9iq',
#    'title': 'How many years have you been using Python?',
#    'ref': '01JJ97XZS5VRQSC09M8VHHNYR2',
#    'properties': {},
#    'validations': {'required': False},
#    'type': 'number'},
#   {'id': 'nYmvq9f223fC',
#    'title': 'Which Python ecosystem do you feel most aligned with? Select all that apply.',
#    'ref': '01JJ97XZS5C6WC13YD9F6EBJF1',
#    'properties': {'randomize': False,
#     'allow_multiple_selection': True,
#     'allow_other_choice': False,
#     'vertical_alignment': True,
#     'choices': [{'id': '0kbUDO64yRXS',
#       'ref': '01JJ97XZS54GVZJHBBR21A9EV6',
#       'label': 'Data Science'},
#      {'id': 'oIo63Nw4bQz1',
#       'ref': '01JJ97XZS5VNHT2GGQD4JTVXRB',
#       'label': 'Web'},
#      {'id': 'cQAt0WYebTjy',
#       'ref': '01JJ97XZS5VMMR1ZCNK9ATEK04',
#       'label': 'Scientific Python'},
#      {'id': 'paps8oo5JNsH',
#       'ref': '01JJ97XZS5SZ3S8M1S2DH54EF5',
#       'label': 'Infrastructure'},
#      {'id': 'hjIOk3BQU5bo',
#       'ref': '01JJ97XZS5P967WPEN5MWP5RE4',
#       'label': 'Prefer not to answer'},
#      {'id': 'NAV341NueSuz',
#       'ref': '01JJ97XZS5JSNCB39479A8APNF',
#       'label': 'Other'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': 'Mug1vmZokYai',
#    'title': 'How many years have you been using documentation tools?',
#    'ref': '01JJ97XZS542PXVQ2MNBB9CDGN',
#    'properties': {},
#    'validations': {'required': False},
#    'type': 'number'},
#   {'id': '2gjT9zqHeeVj',
#    'title': 'In which of the following contexts do you use documentation tools? Select all that apply.',
#    'ref': '01JJ97XZS5QAJSABGFSDNFVGE3',
#    'properties': {'randomize': False,
#     'allow_multiple_selection': True,
#     'allow_other_choice': False,
#     'vertical_alignment': True,
#     'choices': [{'id': 'g9M1jg1HYPt2',
#       'ref': '01JJ97XZS5MXAKQYEQ2523X6JD',
#       'label': 'As a part of my full-time job'},
#      {'id': 'NaZsTliGPjhy',
#       'ref': '01JJ97XZS56GB8ADB250AN7ZT9',
#       'label': 'As a part of my part-time, contract, or other employment'},
#      {'id': 'yahNY2RDwovV',
#       'ref': '01JJ97XZS5QAY2BK3QS4TRW4T5',
#       'label': 'As a part of a side or non-paid project'},
#      {'id': 'i8BrEXfG8dMU',
#       'ref': '01JJ97XZS5C7CX0RQAYG34V5AY',
#       'label': 'I do not use documentation tools'},
#      {'id': 'pKVxilxyGTfa',
#       'ref': '01JJ97XZS5D225JNM6VY41BT8Q',
#       'label': 'Other'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': 'JCYNz5IgOV3G',
#    'title': 'How would you identify your role in your documentation-related projects? Select all that apply.',
#    'ref': '01JJ97XZS6S6J52HC9NZAHR671',
#    'properties': {'randomize': False,
#     'allow_multiple_selection': True,
#     'allow_other_choice': True,
#     'vertical_alignment': True,
#     'choices': [{'id': 'yxJySPi6hUmo',
#       'ref': '01JJ97XZS62ECAZSZ4KVX90G88',
#       'label': 'Developer'},
#      {'id': 'o9rDO9p8aAcb',
#       'ref': '01JJ97XZS6XVNZ1PHTYA08V9QW',
#       'label': 'Data scientist'},
#      {'id': 'luJlOuLHTJiO',
#       'ref': '01JJ97XZS6W0CE2FAEX8PPYACE',
#       'label': 'Educator'},
#      {'id': 'Jbn0q08KcE8r',
#       'ref': '01JJ97XZS65M21N6QE91KNQ2ZF',
#       'label': 'Technical writer'},
#      {'id': 'Hdjak6Ja6W6o',
#       'ref': '01JJ97XZS6BB5HG2G6MG1ZM2C5',
#       'label': 'Community manager'},
#      {'id': 'hbbXHayDAXuK',
#       'ref': '01JJ97XZS6CTA6P9X571GKZF22',
#       'label': 'Testing engineer'},
#      {'id': 'LXJV3R54EsQO',
#       'ref': '01JJ97XZS66QJJPJWYWDAG14WV',
#       'label': 'Extension developer/maintainer'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': 'FqXjSPh0LdQe',
#    'title': 'What documentation engines do you use? Select all that apply.',
#    'ref': '01JJ97XZS65R6YP1PG0ZN7Z2SY',
#    'properties': {'randomize': False,
#     'allow_multiple_selection': True,
#     'allow_other_choice': True,
#     'vertical_alignment': True,
#     'choices': [{'id': 'HvMJkh4UPkTT',
#       'ref': '01JJ97XZS6G3PK1MY2N56VTHFH',
#       'label': 'MyST'},
#      {'id': 'nVke6I1ZkSt3',
#       'ref': '01JJ97XZS6S94RMW7QH4TK0D94',
#       'label': 'Docusaurus'},
#      {'id': 'J5kiNo6chpBa',
#       'ref': '01JJ97XZS6SHJD62SN6QJEFWXA',
#       'label': 'Mkdocs'},
#      {'id': 'xcVSYKoCz6ht',
#       'ref': '01JJ97XZS6B7M0D91V05C8BYRZ',
#       'label': 'JupyterBook'},
#      {'id': 'axHlij9Y254C',
#       'ref': '01JJ97XZS6XM80712124AP2EH0',
#       'label': 'Sphinx'},
#      {'id': 'pDCyA2T6u4Ns',
#       'ref': '01JJ97XZS611J0KK44ERVSYGEH',
#       'label': 'None'},
#      {'id': 'poOp4aK8Oczv',
#       'ref': '01JJ97XZS6Q752XEEDV389ZJSD',
#       'label': 'I don’t know'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': 'v5cvLA2Pif74',
#    'title': 'Where do you deploy your documentation pages?',
#    'ref': '01JJ97XZS6YBQ6QDV56KF3ERM2',
#    'properties': {'randomize': False,
#     'allow_multiple_selection': True,
#     'allow_other_choice': True,
#     'vertical_alignment': True,
#     'choices': [{'id': 'KdyQAmhX5i8L',
#       'ref': '01JJ97XZS6VNZHE93TV7SQQW1X',
#       'label': 'GitHub Pages'},
#      {'id': '9fp83Pnx9fEH',
#       'ref': '01JJ97XZS6P7MDY7Q36BPWKH0B',
#       'label': 'Netlify'},
#      {'id': 'EzvnUSwjN2ZS',
#       'ref': '01JJ97XZS626MN5BS6Y0V98DN5',
#       'label': 'Read The Docs'},
#      {'id': 'w771igPHO2Lz',
#       'ref': '01JJ97XZS6C1K1JAFHAD7GXRDN',
#       'label': 'My institution has its own deployment'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': 'JYhDwq6K9ngb',
#    'title': 'What markup language are you using in your documentation?',
#    'ref': '01JJ97XZS6H1ZCQRKBMJXJHQFX',
#    'properties': {'randomize': False,
#     'allow_multiple_selection': True,
#     'allow_other_choice': True,
#     'vertical_alignment': True,
#     'choices': [{'id': 'nlMFA3XkYxW4',
#       'ref': '01JJ97XZS6N7HA8C6M5A1JZ40R',
#       'label': 'Markdown'},
#      {'id': 'si0OrfZ82ezm',
#       'ref': '01JJ97XZS6KH36EG41M0N3XB3T',
#       'label': 'RST'},
#      {'id': 'SfLhxE7xZ6ys',
#       'ref': '01JJ97XZS6HZ0DAB9XQ726AGPP',
#       'label': 'I don’t know'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': 'iJf6558DvfCC',
#    'title': 'What markup language are you using in your docstrings?',
#    'ref': '01JJ97XZS6N9TK2ZMS30WV5SE9',
#    'properties': {'randomize': False,
#     'allow_multiple_selection': True,
#     'allow_other_choice': True,
#     'vertical_alignment': True,
#     'choices': [{'id': '1KxuUyLfFFRt',
#       'ref': '01JJ97XZS6KD7QS1J97DNNB2ZS',
#       'label': 'Markdown'},
#      {'id': 'oM0t07PnJKp6',
#       'ref': '01JJ97XZS6EQDR0M12KKPCQY4J',
#       'label': 'RST'},
#      {'id': 'TRDks2zxkNrV',
#       'ref': '01JJ97XZS6FBKGD0BPZHV0TXEZ',
#       'label': 'I don’t know'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': 'gwkWry7NEang',
#    'title': 'Which of the following is most important to you in a documentation site?',
#    'ref': '01JJ97XZS6ZSP7WWTQ394D5690',
#    'properties': {'randomize': False,
#     'allow_multiple_selection': True,
#     'allow_other_choice': True,
#     'vertical_alignment': True,
#     'choices': [{'id': 'XGGgxlukXva2',
#       'ref': '01JJ97XZS6MFJ6JKYY2PJDWXMT',
#       'label': 'Ease of use'},
#      {'id': 'ZQvdH3AxpEv4',
#       'ref': '01JJ97XZS63QARKWF2S30RWSCE',
#       'label': 'Performance'},
#      {'id': 'rqLtUqffjzvi',
#       'ref': '01JJ97XZS6HMFZV6QV7SAHHTHB',
#       'label': 'Stability'},
#      {'id': 'jQSqCXKdWZOx',
#       'ref': '01JJ97XZS66FHZY4E331W43Z16',
#       'label': 'Frequent updates'},
#      {'id': 'PMzJ5EwzSh0I',
#       'ref': '01JJ97XZS6PEDTSA4JDF2TQHCW',
#       'label': 'Variety of features'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': '63pAiHQaB0B9',
#    'title': 'Why did you choose the engine you use for your documentation?',
#    'ref': '01JJ97XZS6EWH1C1TF7JPBF0D0',
#    'properties': {'randomize': False,
#     'allow_multiple_selection': True,
#     'allow_other_choice': True,
#     'vertical_alignment': True,
#     'choices': [{'id': '58py21zxVe34',
#       'ref': '01JJ97XZS6CP0NVGV0TNV8CWZ5',
#       'label': 'Ease of use'},
#      {'id': 'FSbB3f2aGpqq',
#       'ref': '01JJ97XZS67J2RJAM69V2696RT',
#       'label': 'Performance'},
#      {'id': 'nDhkIJyEH1sb',
#       'ref': '01JJ97XZS64ZBCDQ987GNF1T7J',
#       'label': 'Stability'},
#      {'id': 'GEbmAjqsi09K',
#       'ref': '01JJ97XZS6706SW87EM2NX3C67',
#       'label': 'Frequent updates'},
#      {'id': 'H20rygZPbTUl',
#       'ref': '01JJ97XZS6EV1D5NMA1D2TDFF8',
#       'label': 'Variety of features'},
#      {'id': 'nghuVTEh4fUB',
#       'ref': '01JJ97XZS6YWWCMQPPE1WXQ07K',
#       'label': 'Other projects in my ecosystem were using it'},
#      {'id': 'NDRMntOSsv0h',
#       'ref': '01JJ97XZS6WTQAWDT8F81FQT3W',
#       'label': 'It was chosen by others on the project'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': 'tu3V6hINA0XP',
#    'title': 'Do you use Sphinx? (Whether working on the project, using it for another project, or developing Sphinx-extensions)',
#    'ref': '01JJ97XZS69T83NWH2NRWG7F0V',
#    'properties': {'randomize': False,
#     'allow_multiple_selection': False,
#     'allow_other_choice': False,
#     'vertical_alignment': True,
#     'choices': [{'id': '3X2VDgbtzkg1',
#       'ref': '01JJ97XZS670ZAH0MH4B8M6X34',
#       'label': 'Yes'},
#      {'id': 'CkofETLi6Jqx',
#       'ref': '01JJ97XZS6KZTCPYJ0259V9CZH',
#       'label': 'No'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': '9viKNpfkgYVP',
#    'title': 'If you aren’t using Sphinx for your documentation, please explain why you chose the one you are using',
#    'ref': '01JJ97XZS61W14PNQAGR9PA9G0',
#    'validations': {'required': False},
#    'type': 'long_text'},
#   {'id': 'oVdcmZqvaBDG',
#    'title': 'How many years have you been using Sphinx?',
#    'ref': '01JJ97XZS67EM1CDZQ5NN0CCGH',
#    'properties': {},
#    'validations': {'required': False},
#    'type': 'number'},
#   {'id': '9MvUwLazwguq',
#    'title': 'What is the main reason you use Sphinx?',
#    'ref': '01JJ97XZS684Z39BHJY74MZTXR',
#    'properties': {'randomize': False,
#     'allow_multiple_selection': False,
#     'allow_other_choice': True,
#     'vertical_alignment': True,
#     'choices': [{'id': 'BO26k18TUYjo',
#       'ref': '01JJ97XZS6FCEKH4RPVJM16DPF',
#       'label': 'Python API documentation generation (docstrings)'},
#      {'id': 'lhi8CZRPafm9',
#       'ref': '01JJ97XZS6RJ8RQ1XF1YFMVDB2',
#       'label': 'Narrative documentation'},
#      {'id': 'AXrbjmxAUvHe',
#       'ref': '01JJ97XZS68XDSS849BBWGV0C1',
#       'label': 'Educational materials'},
#      {'id': 'rhLeWEPsxjxX',
#       'ref': '01JJ97XZS63WRRY6EVC3BSCEQ2',
#       'label': 'Other projects in my ecosystem were using Sphinx'},
#      {'id': 'B8eJ7mFHZu4e',
#       'ref': '01JJ97XZS6EYN58SM0SYC089PX',
#       'label': 'Someone on my team knew how to use Sphinx'},
#      {'id': 'HC4uJj2MTfMy',
#       'ref': '01JJ97XZS6CW8QXQW8P4FHJMCS',
#       'label': 'I joined a project that was already using Sphinx'},
#      {'id': 'XVIwlQu9edOf',
#       'ref': '01JJ97XZS6RZBAWDGAAQCBA0JK',
#       'label': 'Sphinx’s ease of use'},
#      {'id': 'jdgPB9iGOnt4',
#       'ref': '01JJ97XZS63HTYXKN05S2KNMZZ',
#       'label': 'Sphinx’s performance'},
#      {'id': 'WByxPDImTU3H',
#       'ref': '01JJ97XZS69904ZHK2JC9WKEAT',
#       'label': 'Sphinx’s stability'},
#      {'id': 'kixb6I7O2qQv',
#       'ref': '01JJ97XZS6AK3C093W23SVN2XE',
#       'label': 'Sphinx’s release schedule'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': 'HJK6EdbwNZRH',
#    'title': 'Do you follow Sphinx release plans? If so, how? Select all that apply.',
#    'ref': '01JJ97XZS63GA3JT532C4SYR10',
#    'properties': {'randomize': False,
#     'allow_multiple_selection': True,
#     'allow_other_choice': True,
#     'vertical_alignment': True,
#     'choices': [{'id': 'S2hyENzDXS7M',
#       'ref': '01JJ97XZS67EP1X0GZA86F8SNQ',
#       'label': 'I do follow Sphinx release plans by following social media'},
#      {'id': 'xeG2OE3nxDcw',
#       'ref': '01JJ97XZS6PA0668DAN8TPC2F1',
#       'label': 'I do follow Sphinx release plans by managing Sphinx versions'},
#      {'id': 'BvbvsS25T6Af',
#       'ref': '01JJ97XZS626C9C1JEXQTMTKCT',
#       'label': 'I do follow Sphinx release plans by setting up CI runs for pre-releases'},
#      {'id': 'GSrRQnn8J29M',
#       'ref': '01JJ97XZS6HV4RNMPEG97JK584',
#       'label': 'I don’t follow Sphinx release plans'},
#      {'id': 'fuiuFcTsSNDX',
#       'ref': '01JJ97XZS6EN1RH0CACJ20TZQ8',
#       'label': 'Prefer not to answer'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': 'Muw1JyAOBy1p',
#    'title': 'Does your project use custom Sphinx extensions? If so, which ones?',
#    'ref': '01JJ97XZS6B10JPGBAZ3WS0D87',
#    'properties': {'randomize': False,
#     'allow_multiple_selection': False,
#     'allow_other_choice': False,
#     'vertical_alignment': True,
#     'choices': [{'id': '4swZtpAPq1xs',
#       'ref': '01JJ97XZS6RN4A3SNZ0TSCGW3V',
#       'label': 'My project is a custom Sphinx extension(s)'},
#      {'id': 'YU9CVq8Ty6vO',
#       'ref': '01JJ97XZS637PF2DEX5PTK7D4X',
#       'label': 'No, my project does not use custom Sphinx extensions'},
#      {'id': 'fbIHNTMaMzjt',
#       'ref': '01JJ97XZS6PANSHT5ZP1HEHEPC',
#       'label': 'Yes, my project does use custom Sphinx extensions'},
#      {'id': 'vKesAEWhtji1',
#       'ref': '01JJ97XZS6APER13M4PR4C1Q06',
#       'label': 'I don’t know'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': 'IIwlBbYcSJp2',
#    'title': 'What theme(s) do you use? Select all that apply.',
#    'ref': '01JJ97XZS6QS8SFBX5KE1MZPM0',
#    'properties': {'randomize': False,
#     'allow_multiple_selection': True,
#     'allow_other_choice': True,
#     'vertical_alignment': True,
#     'choices': [{'id': 'C0yRaehKUTah',
#       'ref': '01JJ97XZS6JG9WTPFX7Z47T8KM',
#       'label': 'Whatever comes with Sphinx by default'},
#      {'id': 'YM5Jy8Co3HPe',
#       'ref': '01JJ97XZS6FB0X7GMT1M4HDX8D',
#       'label': 'Alabaster'},
#      {'id': 'EPjXGQO9EVWh',
#       'ref': '01JJ97XZS6642VWGZ89ZYW653Q',
#       'label': 'Read The Docs'},
#      {'id': 'QYeE1BJ6y7EH',
#       'ref': '01JJ97XZS6SJCZ7F1S2AF7Q1CN',
#       'label': 'Pydata Sphinx Theme'},
#      {'id': 'AzBsIhU0wbEd',
#       'ref': '01JJ97XZS67X7C67EMGB1H0AJ1',
#       'label': 'Material design'},
#      {'id': 'wPd5PnMbf6Li',
#       'ref': '01JJ97XZS6RN4JKY8CZGKWC0GB',
#       'label': 'I don’t know'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': 'yGwjRmWS3xyq',
#    'title': 'What Sphinx output formats do you use the most?',
#    'ref': '01JJ97XZS611454GRA9AQV5PKB',
#    'properties': {'randomize': False,
#     'allow_multiple_selection': False,
#     'allow_other_choice': True,
#     'vertical_alignment': True,
#     'choices': [{'id': 'LYG3Tyqy4Xnn',
#       'ref': '01JJ97XZS6GC307P95XPCCQG9G',
#       'label': 'HTML'},
#      {'id': 'KRMzFmkIaZwt',
#       'ref': '01JJ97XZS6J6F9ZNJG52HYR365',
#       'label': 'PDF'},
#      {'id': 'CV1PRNJruHlO',
#       'ref': '01JJ97XZS6H451DVDY9MD7355D',
#       'label': 'EPUB'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': 'U3ej3ziRZRWp',
#    'title': 'How comfortable do you feel when working with docutils?',
#    'ref': '01JJ97XZS6PTAZV4Z0CBQMS3V0',
#    'properties': {'randomize': False,
#     'allow_multiple_selection': False,
#     'allow_other_choice': False,
#     'vertical_alignment': True,
#     'choices': [{'id': 'cnttnQzldlVr',
#       'ref': '01JJ97XZS6YEN6CWQE9PHE2K8T',
#       'label': 'Very comfortable'},
#      {'id': 'cZMuFbJSn4bN',
#       'ref': '01JJ97XZS6XSZ2SGYN1BPQF75N',
#       'label': 'Comfortable'},
#      {'id': 'g2YkH5ydM79s',
#       'ref': '01JJ97XZS6C60JV57220XX31MD',
#       'label': 'Neutral'},
#      {'id': 'KFint6nSpcMZ',
#       'ref': '01JJ97XZS6B3EKX90HEHTTY2HN',
#       'label': 'Uncomfortable'},
#      {'id': 'XkXh6tAqE8F7',
#       'ref': '01JJ97XZS66SNDCQ7Y630JZXGJ',
#       'label': 'Very uncomfortable'}]},
#    'validations': {'required': False},
#    'type': 'multiple_choice'},
#   {'id': 'yNpsQKA67IXs',
#    'title': 'What is the biggest challenge you face when searching for documentation on Sphinx internals?',
#    'ref': '01JJ97XZS6S1J320BDZ65SMVJV',
#    'validations': {'required': False},
#    'type': 'long_text'},
#   {'id': 'g9fLcqTMJGDm',
#    'title': 'Please rank the issues you face when working with Sphinx from 1 (least important) to 5 (most important).',
#    'ref': '01JJ97XZS6FMD59FFW9FHPQ1CC',
#    'properties': {'randomize': False,
#     'allow_multiple_selection': True,
#     'choices': [{'id': 'AP4b6xdEPqDJ',
#       'ref': '01JJ97XZS6754MZNEQVZ9FDNPK',
#       'label': 'RST syntax is too complicated 1–5'},
#      {'id': 'vChl6e57vP5G',
#       'ref': '01JJ97XZS68YBJMXTRZYKDRKRP',
#       'label': 'Sphinx is missing features I want 1–5'},
#      {'id': 'didlpVrnhhDL',
#       'ref': '01JJ97XZS6QTP80TXP0BKET6MS',
#       'label': 'Performance issues 1–5'},
#      {'id': 'fb8RnVVbyERq',
#       'ref': '01JJ97XZS6YXAE4KJYHTAKV0JP',
#       'label': 'Sphinx breaks too often 1–5'},
#      {'id': 'zU6536akxuMZ',
#       'ref': '01JJ97XZS6BRZPA1YJAR9BNG0S',
#       'label': 'No native support for Markdown 1–5'}]},
#    'validations': {'required': False},
#    'type': 'ranking'},
#   {'id': 'cFqp60O42ruh',
#    'title': 'Are there any other issues you face when working with Sphinx?',
#    'ref': '01JJ97XZS6AEZ114KQNRY2XXPT',
#    'validations': {'required': False},
#    'type': 'long_text'},
#   {'id': 'RycBuJN7a6HG',
#    'title': 'If there are any features you wish Sphinx had, what would they be?',
#    'ref': '01JJ97XZS6ZT9HXNDPXSDRNS54',
#    'validations': {'required': False},
#    'type': 'long_text'}],
#  '_links': {'display': 'https://s3mu8c5idqn.typeform.com/to/Oq55zKog',
#   'responses': 'https://api.typeform.com/forms/Oq55zKog/responses'}}
